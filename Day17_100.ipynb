# %% [markdown]
# ##  Day 17 Challenge
#
# ### While loop: conitnue , break and exit()

# %% [markdown]
# Go find your Rock, Paper, Scissors game from Day 14 and add the code here before you start. We are going to build upon this game.
#
# 1. Use a loop to repeat the game multiple rounds.
# 2. Keep score of player 1 and player 2.
# 3. End the game when a player wins three rounds using break and exit.
# 4. Use continue to restart the round until one player wins three rounds.
# 5. Your last bit of code should be the results of which player won.

# %%
from getpass import getpass as input

# %%
print(" *****Wecolme to the EPIC battle of 🪨📄✂️******** ")
print()
print(" Instead of rock , paper, scissors, you need to give input as R or P or S")
print()

c1 = 0
c2 = 0
while(True):
    print(" =====Welcome Player 1===== ")
    p1 = input(" Enter you input (R or P or S) ")
    
    if p1 !="R" and p1 !="P" and p1 !="S":
        print()
        print(" Wrong input. We need to start again ")
        print()
        continue 
    print()
    print(" =====Welcome Player 2===== ")
    print()
    p2 = input(" Enter you input (R or P or S) ")

    if p2 !="R" and p2!="P" and p2!="S":
        print()
        print(" Wrong input. We need to start again with Player 1")
        print()
        continue
    print()
    if p1 == "P":
        if p2 == "R":
                print(" Player 1 warp  Player 2  rock with paper. Congrats player 1")
                c1+=1
        elif p2 == "S":
                print(" Player 2 cuts Player 1 paper with scissor. Congrats player 2")
                c2+=1
        else: 
            print(" Opps. Both choose the same option. Its a tie")
    elif p1 == "R":
        if p2 == "P":
                print(" Player 2 warp  Player 1 rock with paper. Congrats player 2")
                c2+=1
        elif p2 == "S":
                print(" Player 1 breaks the Player 2 scissor with rock. Congrats player 1")
                c1+=1
        else: 
            print(" Opps. Both choose the same option. Its a tie")      

    else :
        if p2 == "P":
                print(" Player 1 cuts Player 2 paper with scissor. Congrats player 1")
                c1+=1
        elif p2 == "R":
                print(" Player 2 breaks the Player 1 scissor with rock. Congrats player 2")
                c2+=1
        else: 
            print(" Opps. Both choose the same option. Its a tie")       

    if c1 == 3:
        print(" Current score of Player 1: ", c1)
        print(" Current score of Player 2: ", c2)
        print(" ************************* ")
        print(" Congratulation Player 1  ")
        print(" ************************* ")
        break
    elif c2 == 3:
        print(" Current score of Player 1: ", c1)
        print(" Current score of Player 2: ", c2)
        print("*************************")
        print(" Congratulation Player 2 ")
        print("*************************")
        break
    else:
        print(" Current score of Player 1: ", c1)
        print(" Current score of Player 2: ", c2)
        print()
# Out:
#  *****Wecolme to the EPIC battle of 🪨📄✂️********
#
#  Instead of rock , paper, scissors, you need to give input as R or P or S
#
#  =====Welcome Player 1=====
#  Enter you input (R or P or S) ········
#
#  =====Welcome Player 2=====
#
#  Enter you input (R or P or S) ········
#
#  Player 1 warp  Player 2  rock with paper. Congrats player 1
#  Current score of Player 1:  1
#  Current score of Player 2:  0
#
#  =====Welcome Player 1=====
#  Enter you input (R or P or S) ········
#
#  =====Welcome Player 2=====
#
#  Enter you input (R or P or S) ········
#
#  Player 2 warp  Player 1 rock with paper. Congrats player 2
#  Current score of Player 1:  1
#  Current score of Player 2:  1
#
#  =====Welcome Player 1=====
#  Enter you input (R or P or S) ········
#
#  =====Welcome Player 2=====
#
#  Enter you input (R or P or S) ········
#
#  Opps. Both choose the same option. Its a tie
#  Current score of Player 1:  1
#  Current score of Player 2:  1
#
#  =====Welcome Player 1=====
# ...
